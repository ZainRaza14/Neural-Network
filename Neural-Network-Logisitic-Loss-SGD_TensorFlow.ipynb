# %% [markdown]
# ######*Sibt ul Hussain*
# ----
# ##Goal
#
# Your goal in this assigment is to implement a Logistic Regression loss function based 2 layer neural network using Tensorflow.
#
#
#
# ## For Graphical Debugging:
# You can use the [pycharm](https://www.jetbrains.com/pycharm/download/#section=linux) excellent graphical debugging based IDE.

# %% [markdown]
# ###Logistic Loss
# Given a set of $m$ $d$-dimensional labelled training examples $X$ and their labels $Y $($Y \in \{0, +1\})$.
# Recall that  Logistic Regression uses the hypothesis $\begin{equation} h_\theta(x) = \frac{1}{1+\exp(-x^T\theta)}. \end{equation}$ .
#
# In Logistic Regression we try to optimize (minimize) following cost function (without regularization) to find the optimal (a separator that separates maximially both the classes) separating decision boundary (plane or hyperplane):
#
#
# $$J(\theta) = \frac{1}{m}\sum_{i=1}^{m}\lbrack-y^{(i)}log(h_\theta(x^{(i)})) - (1-y^{(i)})log(1-h_\theta(x^{(i)}))\rbrack+\frac{\lambda}{2}\sum_{i=1}^k \theta_k^2$$

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..

# %% [markdown]
# ### Create some dummy data for testing

# %%
#Please carefully read the code to understand it...
np.random.seed(seed=99)

# make some data up
mean1 = np.array([-5,-5])
mean2 = np.array([2,2])
mean3 = np.array([5,-5])
mean4 = np.array([-4,4])

#Little Challenging...
# mean1 = np.array([-3,-3])
# mean2 = np.array([2,2])
# mean3 = np.array([3,-3])
# mean4 = np.array([-2,2])
cov = [[1.0,0.0],[0.0,1.0]] 

#create some points
nexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)

x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/2,1)),np.zeros((nexamples/2,1))))

plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='r', s=100)
plt.scatter(x3[:,0],x3[:,1], c='g', s=100)
plt.scatter(x4[:,0],x4[:,1], c='g', s=100)



plt.title("Linear Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")

fig_ml_in_10 = plt.gcf()
plt.savefig('linear-class-lr.svg',format='svg')

# %%
mx=np.mean(X,axis=0)
stdx=np.std(X,axis=0)
X=(X-mx)/stdx

# %%
#Implement the SVM using TensorFlow...
import tensorflow as tf

# %%
sess=tf.InteractiveSession()

# %%
alpha=0.9 # learning rate
epochs=2000 # number of epochs..

# %%
nexamples=X.shape[0]

# %%
lembda=tf.constant(0.00)
spacing=np.spacing(1)

Xi=tf.placeholder(tf.float32,shape=[None,2])
Yi=tf.placeholder(tf.float32,shape=[None,1])

#Layer-1 weights....
W1=tf.Variable(tf.truncated_normal([3,2],stddev=0.001),name='Weights') # number of neurons time number of inputs
b1=tf.Variable(tf.truncated_normal([1,3]),name='Bias')

#Layer-2 weights...
W2=tf.Variable(tf.truncated_normal([1,3],stddev=0.001),name='Weights')
b2=tf.Variable(tf.random_normal([1]),name='Bias')

#Layer-1

a1=tf.matmul(Xi,tf.transpose(W1))+b1
print a1.get_shape()
nl1=tf.nn.sigmoid(a1)

#Layer-2
a2=tf.matmul(nl1,tf.transpose(W2))+b2
h=tf.nn.sigmoid(a2)+spacing
print h.get_shape()

cost = tf.add(-tf.mul(Yi,tf.log(h)),-tf.mul(1-Yi,tf.log(1-h)))

data_loss= tf.reduce_sum(cost)/nexamples

reg=tf.reduce_sum(tf.square(W1))+tf.reduce_sum(tf.square(W2))

loss=tf.add(data_loss, lembda * reg * 0.5)

#step = tf.Variable(0, trainable=False)
#rate = tf.train.exponential_decay(0.15, step, 1, 0.9999)
optimizer=tf.train.GradientDescentOptimizer(alpha).minimize(loss)
#optimizer=tf.train.MomentumOptimizer(rate,0.95).minimize(loss)
#optimizer=tf.train.AdamOptimizer(alpha).minimize(loss)


init=tf.initialize_all_variables()
# Out:
# TensorShape([Dimension(None), Dimension(3)])
# TensorShape([Dimension(None), Dimension(1)])

# %%
#with tf.Session() as sess:


sess.run(init)

for e in range (epochs):        
    #shuffle training data 
    [X,Y]=t.shuffle_data(X,Y)
    Xsplit=np.split(X,20)# batch size of 100
    Ysplit=np.split(Y,20) 

    for i in range(len(Xsplit)):
        sess.run(optimizer,feed_dict={Xi:Xsplit[i],Yi:Ysplit[i]})

    if e % 10 ==0:
        print ('After {} Epochs Loss Function Value is {}'.format(e, sess.run(loss,feed_dict={Xi:X,Yi:Y})))

theta=np.array(sess.run(W1))
bias=np.array(sess.run(b1))
res=np.array(sess.run(h,feed_dict={Xi:X}))
print theta, bias
# Out:
# After 0 Epochs Loss Function Value is 0.741738379002
# After 10 Epochs Loss Function Value is 0.692107081413
# After 20 Epochs Loss Function Value is 0.690549075603
# After 30 Epochs Loss Function Value is 0.688713610172
# After 40 Epochs Loss Function Value is 0.686353206635
# After 50 Epochs Loss Function Value is 0.68329846859
# After 60 Epochs Loss Function Value is 0.679443836212
# After 70 Epochs Loss Function Value is 0.674770891666
# After 80 Epochs Loss Function Value is 0.669360041618
# After 90 Epochs Loss Function Value is 0.663292050362
# After 100 Epochs Loss Function Value is 0.656541883945
# After 110 Epochs Loss Function Value is 0.648946166039
# After 120 Epochs Loss Function Value is 0.64027518034
# After 130 Epochs Loss Function Value is 0.630432486534
# After 140 Epochs Loss Function Value is 0.619571506977
# After 150 Epochs Loss Function Value is 0.60809135437
# After 160 Epochs Loss Function Value is 0.596501469612
# After 170 Epochs Loss Function Value is 0.585253000259
# After 180 Epochs Loss Function Value is 0.574659347534
# After 190 Epochs Loss Function Value is 0.56489276886
# After 200 Epochs Loss Function Value is 0.556021511555
# After 210 Epochs Loss Function Value is 0.548046588898
# After 220 Epochs Loss Function Value is 0.540929675102
# After 230 Epochs Loss Function Value is 0.534603834152
# After 240 Epochs Loss Function Value is 0.528977811337
# After 250 Epochs Loss Function Value is 0.523936569691
# After 260 Epochs Loss Function Value is 0.51933825016
# After 270 Epochs Loss Function Value is 0.515019655228
# After 280 Epochs Loss Function Value is 0.510788440704
# After 290 Epochs Loss Function Value is 0.506432592869
# After 300 Epochs Loss Function Value is 0.501728713512
# After 310 Epochs Loss Function Value is 0.49645614624
# After 320 Epochs Loss Function Value is 0.490425020456
# After 330 Epochs Loss Function Value is 0.483471274376
# After 340 Epochs Loss Function Value is 0.475425064564
# After 350 Epochs Loss Function Value is 0.466036558151
# After 360 Epochs Loss Function Value is 0.454909563065
# After 370 Epochs Loss Function Value is 0.441516727209
# After 380 Epochs Loss Function Value is 0.425451099873
# After 390 Epochs Loss Function Value is 0.406833380461
# After 400 Epochs Loss Function Value is 0.386392295361
# After 410 Epochs Loss Function Value is 0.365160107613
# After 420 Epochs Loss Function Value is 0.344113200903
# After 430 Epochs Loss Function Value is 0.324030160904
# After 440 Epochs Loss Function Value is 0.305412322283
# After 450 Epochs Loss Function Value is 0.288515537977
# After 460 Epochs Loss Function Value is 0.273400217295
# After 470 Epochs Loss Function Value is 0.259997487068
# After 480 Epochs Loss Function Value is 0.248171910644
# After 490 Epochs Loss Function Value is 0.237760514021
# After 500 Epochs Loss Function Value is 0.228595376015
# After 510 Epochs Loss Function Value is 0.22051653266
# After 520 Epochs Loss Function Value is 0.213380530477
# After 530 Epochs Loss Function Value is 0.20706179738
# After 540 Epochs Loss Function Value is 0.201449856162
# After 550 Epochs Loss Function Value is 0.196449130774
# After 560 Epochs Loss Function Value is 0.191980719566
# After 570 Epochs Loss Function Value is 0.187974393368
# After 580 Epochs Loss Function Value is 0.184372588992
# After 590 Epochs Loss Function Value is 0.18112462759
# After 600 Epochs Loss Function Value is 0.178187116981
# After 610 Epochs Loss Function Value is 0.175523340702
# After 620 Epochs Loss Function Value is 0.173101872206
# After 630 Epochs Loss Function Value is 0.170895308256
# After 640 Epochs Loss Function Value is 0.168879792094
# After 650 Epochs Loss Function Value is 0.167033970356
# After 660 Epochs Loss Function Value is 0.165340870619
# After 670 Epochs Loss Function Value is 0.163783967495
# After 680 Epochs Loss Function Value is 0.162350282073
# After 690 Epochs Loss Function Value is 0.161027133465
# After 700 Epochs Loss Function Value is 0.159804165363
# After 710 Epochs Loss Function Value is 0.158671662211
# After 720 Epochs Loss Function Value is 0.157621517777
# After 730 Epochs Loss Function Value is 0.156645834446
# After 740 Epochs Loss Function Value is 0.155738040805
# After 750 Epochs Loss Function Value is 0.154892340302
# After 760 Epochs Loss Function Value is 0.15410387516
# After 770 Epochs Loss Function Value is 0.153366997838
# After 780 Epochs Loss Function Value is 0.152677506208
# After 790 Epochs Loss Function Value is 0.152031704783
# After 800 Epochs Loss Function Value is 0.15142647922
# After 810 Epochs Loss Function Value is 0.150858432055
# After 820 Epochs Loss Function Value is 0.150324493647
# After 830 Epochs Loss Function Value is 0.149822607636
# After 840 Epochs Loss Function Value is 0.149349674582
# After 850 Epochs Loss Function Value is 0.148903474212
# After 860 Epochs Loss Function Value is 0.148482814431
# After 870 Epochs Loss Function Value is 0.148085728288
# After 880 Epochs Loss Function Value is 0.147709771991
# After 890 Epochs Loss Function Value is 0.147354364395
# After 900 Epochs Loss Function Value is 0.147017657757
# After 910 Epochs Loss Function Value is 0.146698072553
# After 920 Epochs Loss Function Value is 0.146395027637
# After 930 Epochs Loss Function Value is 0.146107181907
# After 940 Epochs Loss Function Value is 0.145833730698
# After 950 Epochs Loss Function Value is 0.145573750138
# After 960 Epochs Loss Function Value is 0.145325809717
# After 970 Epochs Loss Function Value is 0.145089685917
# After 980 Epochs Loss Function Value is 0.144864529371
# After 990 Epochs Loss Function Value is 0.144649654627
# After 1000 Epochs Loss Function Value is 0.144444584846
# After 1010 Epochs Loss Function Value is 0.144249588251
# After 1020 Epochs Loss Function Value is 0.144060909748
# After 1030 Epochs Loss Function Value is 0.143881350756
# After 1040 Epochs Loss Function Value is 0.143709689379
# After 1050 Epochs Loss Function Value is 0.143545046449
# After 1060 Epochs Loss Function Value is 0.143386438489
# After 1070 Epochs Loss Function Value is 0.143235191703
# After 1080 Epochs Loss Function Value is 0.1430888623
# After 1090 Epochs Loss Function Value is 0.142948687077
# After 1100 Epochs Loss Function Value is 0.142814904451
# After 1110 Epochs Loss Function Value is 0.142684325576
# After 1120 Epochs Loss Function Value is 0.142559632659
# After 1130 Epochs Loss Function Value is 0.142438873649
# After 1140 Epochs Loss Function Value is 0.142322823405
# After 1150 Epochs Loss Function Value is 0.142210841179
# After 1160 Epochs Loss Function Value is 0.142102718353
# After 1170 Epochs Loss Function Value is 0.141998201609
# After 1180 Epochs Loss Function Value is 0.14189748466
# After 1190 Epochs Loss Function Value is 0.141799449921
# After 1200 Epochs Loss Function Value is 0.141705200076
# After 1210 Epochs Loss Function Value is 0.141614675522
# After 1220 Epochs Loss Function Value is 0.141524687409
# After 1230 Epochs Loss Function Value is 0.141438692808
# After 1240 Epochs Loss Function Value is 0.141355097294
# After 1250 Epochs Loss Function Value is 0.14127458632
# After 1260 Epochs Loss Function Value is 0.141195639968
# After 1270 Epochs Loss Function Value is 0.141119107604
# After 1280 Epochs Loss Function Value is 0.141045227647
# After 1290 Epochs Loss Function Value is 0.140972226858
# After 1300 Epochs Loss Function Value is 0.140902012587
# After 1310 Epochs Loss Function Value is 0.140833511949
# After 1320 Epochs Loss Function Value is 0.140767082572
# After 1330 Epochs Loss Function Value is 0.140701770782
# After 1340 Epochs Loss Function Value is 0.140638306737
# After 1350 Epochs Loss Function Value is 0.140576452017
# After 1360 Epochs Loss Function Value is 0.140516087413
# After 1370 Epochs Loss Function Value is 0.140459045768
# After 1380 Epochs Loss Function Value is 0.140399560332
# After 1390 Epochs Loss Function Value is 0.140343382955
# After 1400 Epochs Loss Function Value is 0.140288770199
# After 1410 Epochs Loss Function Value is 0.140234455466
# After 1420 Epochs Loss Function Value is 0.140181928873
# After 1430 Epochs Loss Function Value is 0.140130221844
# After 1440 Epochs Loss Function Value is 0.140079796314
# After 1450 Epochs Loss Function Value is 0.140030428767
# After 1460 Epochs Loss Function Value is 0.139981761575
# After 1470 Epochs Loss Function Value is 0.139934390783
# After 1480 Epochs Loss Function Value is 0.139887601137
# After 1490 Epochs Loss Function Value is 0.13984182477
# After 1500 Epochs Loss Function Value is 0.139796838164
# After 1510 Epochs Loss Function Value is 0.139752984047
# After 1520 Epochs Loss Function Value is 0.139709383249
# After 1530 Epochs Loss Function Value is 0.13966716826
# After 1540 Epochs Loss Function Value is 0.139624893665
# After 1550 Epochs Loss Function Value is 0.139583662152
# After 1560 Epochs Loss Function Value is 0.139543369412
# After 1570 Epochs Loss Function Value is 0.139503389597
# After 1580 Epochs Loss Function Value is 0.139466762543
# After 1590 Epochs Loss Function Value is 0.139425858855
# After 1600 Epochs Loss Function Value is 0.139387831092
# After 1610 Epochs Loss Function Value is 0.139350488782
# After 1620 Epochs Loss Function Value is 0.139313995838
# After 1630 Epochs Loss Function Value is 0.139277800918
# After 1640 Epochs Loss Function Value is 0.139241576195
# After 1650 Epochs Loss Function Value is 0.13920673728
# After 1660 Epochs Loss Function Value is 0.139173060656
# After 1670 Epochs Loss Function Value is 0.139137208462
# After 1680 Epochs Loss Function Value is 0.139103427529
# After 1690 Epochs Loss Function Value is 0.139069974422
# After 1700 Epochs Loss Function Value is 0.139037385583
# After 1710 Epochs Loss Function Value is 0.139005184174
# After 1720 Epochs Loss Function Value is 0.138972744346
# After 1730 Epochs Loss Function Value is 0.138941377401
# After 1740 Epochs Loss Function Value is 0.138909325004
# After 1750 Epochs Loss Function Value is 0.138878360391
# After 1760 Epochs Loss Function Value is 0.138848111033
# After 1770 Epochs Loss Function Value is 0.138817876577
# After 1780 Epochs Loss Function Value is 0.138788193464
# After 1790 Epochs Loss Function Value is 0.138758063316
# After 1800 Epochs Loss Function Value is 0.13872872293
# After 1810 Epochs Loss Function Value is 0.138699874282
# After 1820 Epochs Loss Function Value is 0.13867174089
# After 1830 Epochs Loss Function Value is 0.138643145561
# After 1840 Epochs Loss Function Value is 0.138615399599
# After 1850 Epochs Loss Function Value is 0.138587653637
# After 1860 Epochs Loss Function Value is 0.138560056686
# After 1870 Epochs Loss Function Value is 0.138532370329
# After 1880 Epochs Loss Function Value is 0.138505369425
# After 1890 Epochs Loss Function Value is 0.138478785753
# After 1900 Epochs Loss Function Value is 0.138452887535
# After 1910 Epochs Loss Function Value is 0.138425990939
# After 1920 Epochs Loss Function Value is 0.138400971889
# After 1930 Epochs Loss Function Value is 0.13837480545
# After 1940 Epochs Loss Function Value is 0.138348937035
# After 1950 Epochs Loss Function Value is 0.138323798776
# After 1960 Epochs Loss Function Value is 0.138298735023
# After 1970 Epochs Loss Function Value is 0.138274118304
# After 1980 Epochs Loss Function Value is 0.138249233365
# After 1990 Epochs Loss Function Value is 0.138224363327
# [[ 4.27572823  4.43134594]
#  [ 0.0169351  -0.06761637]
#  [-4.70439577 -4.60751629]] [[-3.99384189 -1.84212148 -4.14210701]]

# %%
npts=1000
ax=plt.gca()
x0spr = max(X[:,0])-min(X[:,0])
x1spr = max(X[:,1])-min(X[:,1])

tx=np.random.rand(npts,2)
tx[:,0] = tx[:,0]*x0spr + min(X[:,0])
tx[:,1] = tx[:,1]*x1spr + min(X[:,1])

print tx.min(), X.min(), tx.max(), X.max()
#tx=np.hstack((tx,np.ones((tx.shape[0],1))))
print tx.shape

cs= np.array(sess.run(h,feed_dict={Xi:tx}))  > 0.5
#print cs.flatten(), np.unique(cs).flatten()

ax.scatter(tx[:,0],tx[:,1],c=cs, alpha=.75)

ax.hold(True)
ax.scatter(X[:,0],X[:,1],
             c=list(map(lambda x:'r' if x==1 else 'lime',Y),), 
             linewidth=0,s=25,alpha=1)
ax.set_xlim([min(X[:,0]), max(X[:,0])])
ax.set_ylim([min(X[:,1]), max(X[:,1])])
# Out:
# -1.77731667666 -1.78273724891 2.00253817928 2.00705094357
# (1000, 2)
# (-1.6320596271601668, 1.8546373948001498)

# %%
Xt=sess.run(nl1,feed_dict={Xi:X})

# %%
print Xt.shape, Y.shape
# Out:
# (1000, 3) (1000, 1)

# %%
# %matplotlib notebook #make plot interactive, you can play

# %%
d=np.array(sess.run(b2)).flatten()# plane bias
normal=np.array(sess.run(W2)).flatten() # plane normal

# %%
print normal,d
# Out:
# [  9.3750639   -0.54476649  10.21105099] [-4.58843756]

# %% [markdown]
# ## Interactive Plot to see what our second layer neurons are doing.
# They are mapping the input in such a way that positive class become distinct from the negative class.
#
# *Please use mouse to rotate the figure and see the mapping of first hidden layer*

# %%
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#ax.scatter(xs, ys, zs, c=c, marker=m)

ax.scatter(Xt[500:,0],Xt[500:,1],Xt[500:,2], c='r', s=100)
ax.scatter(Xt[:500,0],Xt[:500,1],Xt[500:,2], c='g', s=100)

# create x,y
# xx, yy = np.meshgrid(np.arange(0,1,0.1), np.arange(0,1,0.1))

# # calculate corresponding z
# z = (-normal[2] * xx - normal[0] * yy - d) * 1. / normal[1]

# ax.plot_surface(z,xx,yy, rstride=1, cstride=1,
#                    #facecolors=cm.jet(N),
#                    #linewidth=0, antialiased=False, shade=False
#                   alpha=0.4)

ax.set_xlabel('Neuron-1 Axis')
ax.set_ylabel('Neuron-2 Axis')
ax.set_zlabel('Neuron-3 Axis')
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.scatter(Xt[500:,0],Xt[500:,1], c='g', s=100)
plt.scatter(Xt[:500,0],Xt[:500,1], c='r', s=100)

plt.title("Mapping by 1st Hidden of Neural Network")
plt.xlabel("Mapped feature by Neuron 1")
plt.ylabel("Mapped feature by Neuron 2")

fig_ml_in_10 = plt.gcf()
plt.savefig('nn-transformation-layer-1.svg',format='svg')
